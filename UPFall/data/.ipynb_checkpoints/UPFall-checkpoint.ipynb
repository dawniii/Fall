# %% [markdown]
# ### UPFall数据集

# %% [markdown]
# 该数据集是公开可用的，它包含 17 名受试者在每次 3 次尝试中执行的 11 项活动。

# %% [markdown]
# Activity ID     Description     Duration(s)
# - 1   Falling forward using hands     10
# - 2   Falling forward using knees     10
# - 3   Falling backwards               10(文件里没有)
# - 4   Falling sidewards               10
# - 5   Falling sitting in empty chair  10
# - 6   Walking                         60
# - 7   Standing                        60
# - 8   Sitting                         60
# - 9   Picking up an object            10
# - 10  Jumping                         30
# - 11  Laying                          60
#
#
# - 活动 11 中受试者 8 的试验 2 和 3 不可用

# %% [markdown]
# ### 完整数据
# - 保存在一个csv文件夹中
# - 本实验输入数据一共30个特征

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
f='E:/Fall/UPFall/data/CompleteDataSet.csv'
df=pd.read_csv(f,header=None,skiprows=2)
df=df[[1,2,3,4,5,6,8,9,10,11,12,13,15,16,17,18,19,20,22,23,24,25,26,27,29,30,31,32,33,34,43,44,45,46]]
columns=['Ankle_ACC_X','Ankle_ACC_Y','Ankle_ACC_Z','Ankle_ANG_X','Ankle_ANG_Y','Ankle_ANG_Z','RP_ACC_X','RP_ACC_Y','RP_ACC_Z','RP_ANG_X','RP_ANG_Y','RP_ANG_Z',
         'BELT_ACC_X', 'BELT_ACC_Y', 'BELT_ACC_Z', 'BELT_ANG_X', 'BELT_ANG_Y', 'BELT_ANG_Z','NECK_ACC_X','NECK_ACC_Y','NECK_ACC_Z','NECK_ANG_X','NECK_ANG_Y','NECK_ANG_Z','WRST_ACC_X','WRST_ACC_Y','WRST_ACC_Z','WRST_ANG_X','WRST_ANG_Y','WRST_ANG_Z',
         'Subject','Activity','Trial','Tag']
df = pd.DataFrame(df.values, columns=columns)
display(df)
# Out:
#         Ankle_ACC_X  Ankle_ACC_Y  Ankle_ACC_Z  Ankle_ANG_X  Ankle_ANG_Y  \
# 0            -1.005        0.229       -0.083       -0.671        0.488
# 1            -1.005        0.228       -0.082       -3.415       -0.549
# 2            -1.005        0.231       -0.079       -2.622       -1.402
# 3            -1.005        0.231       -0.079       -2.561       -2.195
# 4            -1.008        0.229       -0.072       -3.537       -2.073
# ...             ...          ...          ...          ...          ...
# 294673        0.247        0.948        0.120       -1.646        0.488
# 294674        0.247        0.952        0.121       -1.037        0.732
# 294675        0.246        0.952        0.115       -0.610        0.732
# 294676        0.249        0.949        0.120       -0.854        0.427
# 294677        0.249        0.949        0.120       -0.610        0.915
#
#         Ankle_ANG_Z  RP_ACC_X  RP_ACC_Y  RP_ACC_Z  RP_ANG_X  ...  WRST_ACC_X  \
# ...

# %%
plt.figure(figsize=(18,15))
plt.plot(df['Ankle_ACC_X'],label='Ankle_ACC_X')
plt.plot(df['Subject'],label='Subject')
plt.plot(df['Activity'],label='Activity')
plt.plot(df['Trial'],label='Trial')
plt.plot(df['Tag'],label='Tag')
plt.legend()

# %% [markdown]
# #### 实验者1 5种不同类型跌倒的3次实验

# %%
plt.figure(figsize=(18,16))
for fall in range(5):
    for trial in range(3):
        plt.subplot(5,3,fall*3+trial+1)
        dk=df.loc[df['Activity']==fall+1]
        dk=dk.loc[df['Subject']==1]
        dk=dk.loc[df['Trial']==trial+1]
        plt.plot(dk['Ankle_ACC_X'])
        plt.plot(dk['Tag'])

# %%
dk=df.loc[df['Activity']==5]
dk=dk.loc[df['Subject']==1]
dk=dk.loc[df['Trial']==2]
dk=dk.loc[df['Tag']==5]
display(dk)
# Out:
#       Ankle_ACC_X  Ankle_ACC_Y  Ankle_ACC_Z  Ankle_ANG_X  Ankle_ANG_Y  \
# 2469       -1.021        0.128       -0.106        4.878        5.732
# 2470       -1.021        0.128       -0.106       13.476        0.549
# 2471       -1.004        0.170       -0.075       -0.549        8.171
# 2472       -1.005        0.228       -0.118       -9.451       12.927
# 2473       -1.008        0.195       -0.132       -6.037       17.134
# 2474       -1.008        0.195       -0.132       -6.707       20.915
# 2475       -1.009        0.188       -0.166        1.037       22.744
# 2476       -1.003        0.208       -0.208       -7.012       18.720
# 2477       -1.003        0.208       -0.208       -5.549       12.134
# 2478       -1.003        0.190       -0.202       -4.878        9.756
# 2479       -1.003        0.190       -0.202       -2.988        5.366
# 2480       -0.998        0.218       -0.209       -7.012        6.220
# ...

# %% [markdown]
# #### 一次非跌倒

# %%
dk=df.loc[df['Activity']==6]
dk=dk.loc[df['Subject']==1]
dk=dk.loc[df['Trial']==1]
#调整dk的标号
dk.reset_index(drop=True, inplace=True)
display(dk)
plt.plot(dk['Ankle_ACC_X'])
# Out:
#       Ankle_ACC_X  Ankle_ACC_Y  Ankle_ACC_Z  Ankle_ANG_X  Ankle_ANG_Y  \
# 0          -1.398        0.154       -0.100       10.854       10.000
# 1          -1.398        0.154       -0.100       20.793       19.756
# 2          -2.010        0.659       -0.078       40.915       37.134
# 3          -2.010        0.659       -0.078      115.549       29.085
# 4          -1.099       -0.044       -0.790      -51.098        5.732
# ...           ...          ...          ...          ...          ...
# 1128       -1.097        0.341        0.442     -100.854       68.598
# 1129       -1.244        0.283        0.076       -8.049       52.683
# 1130       -1.244        0.283        0.076      -21.585       43.415
# 1131       -0.993        0.209       -0.130      -13.049       26.280
# 1132       -1.028        0.242       -0.049       -1.037        7.866
#
#       Ankle_ANG_Z  RP_ACC_X  RP_ACC_Y  RP_ACC_Z  RP_ANG_X  ...  WRST_ACC_X  \
# ...

# %% [markdown]
# ### 跌倒窗口处理

# %%
#窗口大小为40
len(df)
segments=[]
labels=[]
for subject in range(11):
    for fall in range(5):
        for trial in range(3):
            dk=df.loc[df['Activity']==fall+1]
            dk=dk.loc[df['Subject']==subject+1]
            dk=dk.loc[df['Trial']==trial+1]
            dk=dk.loc[df['Tag']==fall+1]
            #调整dk的标号
            dk.reset_index(drop=True, inplace=True)
            segments.append(np.array(dk.head(40)))
            labels.append(1)
labels=np.asarray(pd.get_dummies(labels),dtype=np.float32)#是利用pandas实现one hot encode的方式。
reshaped_segments=np.asarray(segments)
print(reshaped_segments.shape)
print(labels.shape)
# Out:
# (165,)
# (165, 1)
# C:\Users\Lenovo\anaconda3\lib\site-packages\numpy\core\_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
